# %%
import matplotlib.pyplot as plt
x = np.random.normal(170,10,250)
plt.hist(x)
plt.show(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [2], line 4
#       2 x = np.random.normal(170,10,250)
#       3 plt.hist(x)
# ----> 4 plt.show(x)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\pyplot.py:411, in show(*args, **kwargs)
#     367 """
#     368 Display all open figures.
#     369
#    (...)
#     408 explicitly there.
#     409 """
#     410 _warn_if_gui_out_of_main_thread()
# --> 411 return _get_backend_mod().show(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib_inline\backend_inline.py:98, in show(close, block)
#      95 show._to_draw = []
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
# ...
